# %%
import pandas as pd

# %%
data = pd.read_csv("../data/Aussie_Wines_Plotting.csv")
data.head()
# Out:
#     id    country                                        description  \
# 0   77  Australia  This medium-bodied Chardonnay features aromas ...
# 1   83  Australia  Pale copper in hue, this wine exudes passion f...
# 2  123  Australia  The blend is roughly two-thirds Shiraz and one...
# 3  191  Australia  From the little-known region of Padthaway, thi...
# 4  232  Australia  Lifted cedar and pine notes interspersed with ...
#
#                   designation  points  price         province  \
# 0    Made With Organic Grapes      86   18.0  South Australia
# 1           Jester Sangiovese      86   20.0  South Australia
# 2               Parson's Flat      92   40.0  South Australia
# 3  The Trial of John Montford      87   30.0  South Australia
# 4             Red Belly Black      85   12.0  South Australia
#
#           region_1  region_2     taster_name taster_twitter_handle  \
# 0  South Australia       NaN  Joe Czerwinski                @JoeCz
# ...

# %%
des_data = data.description
des_data.head()
# Out:
# 0    gdfgdfgf
# 1    gdfgdfgf
# 2    gdfgdfgf
# 3    gdfgdfgf
# 4    gdfgdfgf
# Name: description, dtype: object

# %%
def formats(str):
    return str.replace(",", ".")

# %%
for d in des_data:
    data.loc[data['description'] == d, 'description'] = "gdfgdfgf"

# %%
des_data = data.description
des_data.head()
# Out:
# 0    gdfgdfgf
# 1    gdfgdfgf
# 2    gdfgdfgf
# 3    gdfgdfgf
# 4    gdfgdfgf
# Name: description, dtype: object

# %%
data.head()
# Out:
#     id    country description                 designation  points  price  \
# 0   77  Australia    gdfgdfgf    Made With Organic Grapes      86   18.0
# 1   83  Australia    gdfgdfgf           Jester Sangiovese      86   20.0
# 2  123  Australia    gdfgdfgf               Parson's Flat      92   40.0
# 3  191  Australia    gdfgdfgf  The Trial of John Montford      87   30.0
# 4  232  Australia    gdfgdfgf             Red Belly Black      85   12.0
#
#           province         region_1  region_2     taster_name  \
# 0  South Australia  South Australia       NaN  Joe Czerwinski
# 1  South Australia     McLaren Vale       NaN  Joe Czerwinski
# 2  South Australia        Padthaway       NaN  Joe Czerwinski
# 3  South Australia        Padthaway       NaN  Joe Czerwinski
# 4  South Australia  South Australia       NaN             NaN
#
#   taster_twitter_handle                                              title  \
# ...
